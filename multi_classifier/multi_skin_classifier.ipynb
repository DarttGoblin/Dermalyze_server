# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications import EfficientNetV2B0
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
# Configs
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 10
DATA_DIR = '/content/drive/MyDrive/multiclass_data'
CSV_PATH = '/content/drive/MyDrive/multiclass_data/HAM10000_metadata.csv'

# %%
# Load metadata
df = pd.read_csv(CSV_PATH)

# %%
# Get class labels
class_names = os.listdir(DATA_DIR)
class_names = sorted([cls for cls in class_names if os.path.isdir(os.path.join(DATA_DIR, cls))])
class_to_idx = {cls: i for i, cls in enumerate(class_names)}

# %%
# Filter metadata to include only images in multiclass_data
valid_files = []
for cls in class_names:
    valid_files += [f for f in os.listdir(os.path.join(DATA_DIR, cls)) if f.endswith('.jpg')]
valid_ids = [f[:-4] for f in valid_files]
df = df[df['image_id'].isin(valid_ids)].copy()

# %%
# Assign label indices
df['label'] = df['dx'].map(class_to_idx)

# Encode metadata
df['sex'] = LabelEncoder().fit_transform(df['sex'].fillna('unknown'))
df['age'] = df['age'].fillna(df['age'].mean()) / 100.0  # Normalize
loc_encoded = OneHotEncoder(sparse_output=False).fit_transform(df['localization'].fillna('unknown').values.reshape(-1, 1))
df['localization'] = loc_encoded.tolist()

# %%
# Load data
def load_data(df):
    images, ages, sexes, locs, labels = [], [], [], [], []
    for _, row in df.iterrows():
        cls = row['dx']
        img_path = os.path.join(DATA_DIR, cls, f"{row['image_id']}.jpg")
        img = load_img(img_path, target_size=IMG_SIZE)
        img_array = img_to_array(img) / 255.0
        images.append(img_array)
        ages.append(row['age'])
        sexes.append(row['sex'])
        locs.append(row['localization'])
        labels.append(row['label'])
    return (
        np.array(images),
        np.array(ages).reshape(-1, 1),
        np.array(sexes).reshape(-1, 1),
        np.array(locs),
        tf.keras.utils.to_categorical(np.array(labels), num_classes=len(class_names))
    )

# %%
images, ages, sexes, locs, labels = load_data(df)

# Train/val split
X_train, X_val, age_train, age_val, sex_train, sex_val, loc_train, loc_val, y_train, y_val = train_test_split(
    images, ages, sexes, locs, labels, test_size=0.2, stratify=labels.argmax(axis=1), random_state=42
)

# %%
# Build model
img_input = layers.Input(shape=IMG_SIZE + (3,))
age_input = layers.Input(shape=(1,))
sex_input = layers.Input(shape=(1,))
loc_input = layers.Input(shape=(locs.shape[1],))

base = EfficientNetV2B0(include_top=False, weights='imagenet', input_tensor=img_input)
x = layers.GlobalAveragePooling2D()(base.output)

meta = layers.Concatenate()([age_input, sex_input, loc_input])
meta = layers.Dense(32, activation='relu')(meta)

combined = layers.Concatenate()([x, meta])
combined = layers.Dense(64, activation='relu')(combined)
combined = layers.Dropout(0.5)(combined)
output = layers.Dense(len(class_names), activation='softmax')(combined)

model = Model(inputs=[img_input, age_input, sex_input, loc_input], outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Compile and train
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(
    [X_train, age_train, sex_train, loc_train], y_train,
    validation_data=([X_val, age_val, sex_val, loc_val], y_val),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE
)
# Out:
# Epoch 1/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 447s 8s/step - accuracy: 0.6322 - loss: 0.8355 - val_accuracy: 0.2634 - val_loss: 1.3408
# Epoch 2/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 359s 7s/step - accuracy: 0.8190 - loss: 0.5011 - val_accuracy: 0.3146 - val_loss: 1.1976
# Epoch 3/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 382s 7s/step - accuracy: 0.8734 - loss: 0.3618 - val_accuracy: 0.3504 - val_loss: 1.0762
# Epoch 4/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 407s 8s/step - accuracy: 0.8966 - loss: 0.3106 - val_accuracy: 0.5908 - val_loss: 1.1912
# Epoch 5/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 445s 8s/step - accuracy: 0.9113 - loss: 0.2421 - val_accuracy: 0.2583 - val_loss: 1.6136
# Epoch 6/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 405s 8s/step - accuracy: 0.9528 - loss: 0.1609 - val_accuracy: 0.2864 - val_loss: 1.5517
# Epoch 7/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 444s 8s/step - accuracy: 0.9528 - loss: 0.1555 - val_accuracy: 0.2711 - val_loss: 1.6144
# Epoch 8/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 414s 8s/step - accuracy: 0.9593 - loss: 0.1179 - val_accuracy: 0.2634 - val_loss: 1.9408
# Epoch 9/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 355s 7s/step - accuracy: 0.9640 - loss: 0.1200 - val_accuracy: 0.2916 - val_loss: 1.3647
# Epoch 10/10
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 397s 8s/step - accuracy: 0.9633 - loss: 0.0958 - val_accuracy: 0.2634 - val_loss: 2.2879

# %%
# Save model
model.export('multiclass_skin_classifier')
# Out:
# Saved artifact at 'multiclass_skin_classifier'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor'), TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor_1'), TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor_2'), TensorSpec(shape=(None, 13), dtype=tf.float32, name='keras_tensor_3')]
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   136208194292816: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136208215210704: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   136208194291088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194293968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194294160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208215209552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208215210128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194294736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194296656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194295888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194294352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194296464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194298192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194297424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194295696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194297808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194299152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194298576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194300688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194301648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194300880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194298384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194302608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194301072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194303376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194301840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194299920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194304912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194302224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194303760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194305104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208194302992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208822544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208823504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208824464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208823696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208822736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208825424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208825040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208826384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208825616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208823312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208823120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208827536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208828496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208827728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208826192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208826960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208829648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208830608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208829840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208828304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208830032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208831952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208832912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208832144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208830800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208833872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208833488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208834832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208834064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208831760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208835792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208835984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208834256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208836368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208832336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208208837520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136208